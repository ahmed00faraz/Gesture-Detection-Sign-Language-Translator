# %% [markdown]
# # 1. Import and install dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoint Using MP Holistics

# %%
mp_holistic = mp.solutions.holistic  # Holistic model
mp_drawing = mp.solutions.drawing_utils  # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Color Conversion
    image.flags.writeable = False # image is unwriteable
    results = model.process(image) # make predictable
    image.flags.writeable = True # image is writeable again
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Color Conversion
    return image, results

# %%
def draw_styled_landmarks(image, results):
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(
            image, 
            results.pose_landmarks, 
            mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
            mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2),
        )
    if results.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, 
            results.left_hand_landmarks, 
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
            mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2),
        )
    if results.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, 
            results.right_hand_landmarks, 
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
        )

# %% [markdown]
# # 3. Extract Keypoints Values for Training and Testing

# %%
def extract_keypoints(results):
    pose = (
        np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        if results.pose_landmarks
        else np.zeros(33 * 4)  # 33 pose landmarks, each with 4 attributes
    )
    lh = (
        np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten()
        if results.left_hand_landmarks
        else np.zeros(21 * 3)  # 21 hand landmarks, each with 3 attributes
    )
    rh = (
        np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten()
        if results.right_hand_landmarks
        else np.zeros(21 * 3)  # 21 hand landmarks, each with 3 attributes
    )
    return np.concatenate([pose, lh, rh])

# %% [markdown]
# # 4. Setup Folders for collection

# %%
DATA_PATH = os.path.join('MP_DATA_1')

# Ensure the data path exists
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# Actions that we try to detect
actions = np.array(['Hello','Thanks','I Love you'])

# thirty videos worth of data
no_sequences = 30

# thirty frames per video
sequence_length = 30

# %%
# Create directories for each action and sequence
for action in actions:
    for sequence in range(no_sequences):
        dir_path = os.path.join(DATA_PATH, action, str(sequence))
        try:
            os.makedirs(dir_path, exist_ok=True)  # Use exist_ok to handle already existing directories
            print(f"Created directory: {dir_path}")
        except Exception as e:
            print(f"Error creating directory {dir_path}: {e}")
# Out:
# Created directory: MP_DATA_1\Hello\0
# Created directory: MP_DATA_1\Hello\1
# Created directory: MP_DATA_1\Hello\2
# Created directory: MP_DATA_1\Hello\3
# Created directory: MP_DATA_1\Hello\4
# Created directory: MP_DATA_1\Hello\5
# Created directory: MP_DATA_1\Hello\6
# Created directory: MP_DATA_1\Hello\7
# Created directory: MP_DATA_1\Hello\8
# Created directory: MP_DATA_1\Hello\9
# Created directory: MP_DATA_1\Hello\10
# Created directory: MP_DATA_1\Hello\11
# Created directory: MP_DATA_1\Hello\12
# Created directory: MP_DATA_1\Hello\13
# Created directory: MP_DATA_1\Hello\14
# Created directory: MP_DATA_1\Hello\15
# Created directory: MP_DATA_1\Hello\16
# Created directory: MP_DATA_1\Hello\17
# Created directory: MP_DATA_1\Hello\18
# Created directory: MP_DATA_1\Hello\19
# Created directory: MP_DATA_1\Hello\20
# Created directory: MP_DATA_1\Hello\21
# Created directory: MP_DATA_1\Hello\22
# Created directory: MP_DATA_1\Hello\23
# Created directory: MP_DATA_1\Hello\24
# Created directory: MP_DATA_1\Hello\25
# Created directory: MP_DATA_1\Hello\26
# Created directory: MP_DATA_1\Hello\27
# Created directory: MP_DATA_1\Hello\28
# Created directory: MP_DATA_1\Hello\29
# Created directory: MP_DATA_1\Thanks\0
# Created directory: MP_DATA_1\Thanks\1
# Created directory: MP_DATA_1\Thanks\2
# Created directory: MP_DATA_1\Thanks\3
# Created directory: MP_DATA_1\Thanks\4
# Created directory: MP_DATA_1\Thanks\5
# Created directory: MP_DATA_1\Thanks\6
# Created directory: MP_DATA_1\Thanks\7
# Created directory: MP_DATA_1\Thanks\8
# Created directory: MP_DATA_1\Thanks\9
# Created directory: MP_DATA_1\Thanks\10
# Created directory: MP_DATA_1\Thanks\11
# Created directory: MP_DATA_1\Thanks\12
# Created directory: MP_DATA_1\Thanks\13
# Created directory: MP_DATA_1\Thanks\14
# Created directory: MP_DATA_1\Thanks\15
# Created directory: MP_DATA_1\Thanks\16
# Created directory: MP_DATA_1\Thanks\17
# Created directory: MP_DATA_1\Thanks\18
# Created directory: MP_DATA_1\Thanks\19
# Created directory: MP_DATA_1\Thanks\20
# Created directory: MP_DATA_1\Thanks\21
# Created directory: MP_DATA_1\Thanks\22
# Created directory: MP_DATA_1\Thanks\23
# Created directory: MP_DATA_1\Thanks\24
# Created directory: MP_DATA_1\Thanks\25
# Created directory: MP_DATA_1\Thanks\26
# Created directory: MP_DATA_1\Thanks\27
# Created directory: MP_DATA_1\Thanks\28
# Created directory: MP_DATA_1\Thanks\29
# Created directory: MP_DATA_1\I Love you\0
# Created directory: MP_DATA_1\I Love you\1
# Created directory: MP_DATA_1\I Love you\2
# Created directory: MP_DATA_1\I Love you\3
# Created directory: MP_DATA_1\I Love you\4
# Created directory: MP_DATA_1\I Love you\5
# Created directory: MP_DATA_1\I Love you\6
# Created directory: MP_DATA_1\I Love you\7
# Created directory: MP_DATA_1\I Love you\8
# Created directory: MP_DATA_1\I Love you\9
# Created directory: MP_DATA_1\I Love you\10
# Created directory: MP_DATA_1\I Love you\11
# Created directory: MP_DATA_1\I Love you\12
# Created directory: MP_DATA_1\I Love you\13
# Created directory: MP_DATA_1\I Love you\14
# Created directory: MP_DATA_1\I Love you\15
# Created directory: MP_DATA_1\I Love you\16
# Created directory: MP_DATA_1\I Love you\17
# Created directory: MP_DATA_1\I Love you\18
# Created directory: MP_DATA_1\I Love you\19
# Created directory: MP_DATA_1\I Love you\20
# Created directory: MP_DATA_1\I Love you\21
# Created directory: MP_DATA_1\I Love you\22
# Created directory: MP_DATA_1\I Love you\23
# Created directory: MP_DATA_1\I Love you\24
# Created directory: MP_DATA_1\I Love you\25
# Created directory: MP_DATA_1\I Love you\26
# Created directory: MP_DATA_1\I Love you\27
# Created directory: MP_DATA_1\I Love you\28
# Created directory: MP_DATA_1\I Love you\29

# %% [markdown]
# # 5. Collect Keypoint values for Training and Testing

# %%
# from time import sleep
# cap = cv2.VideoCapture(0)

# # Set MediaPipe model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     # Loop through actions
#     for action in actions:
#         sleep(5)
#         # Loop through sequences (videos)
#         for sequence in range(no_sequences):
#             sleep(1)
#             # Loop through frames
#             for frame_num in range(sequence_length):
#                 # Read feed
#                 ret, frame = cap.read()
#                 if not ret:
#                     print("Failed to read from webcam.")
#                     break
                
#                 # Make detection
#                 image, results = mediapipe_detection(frame, holistic)
                
#                 # Draw landmarks
#                 draw_styled_landmarks(image, results)
                
#                 # Display starting message
#                 if frame_num == 0:
#                     cv2.putText(
#                         image, 'STARTING COLLECTION', (120, 200),
#                         cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA
#                     )
#                     cv2.putText(
#                         image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA
#                     )
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
#                     cv2.waitKey(500)  # Pause for half a second
#                 else:
#                     cv2.putText(
#                         image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA
#                     )
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
                
#                 # Export keypoints
#                 keypoints = extract_keypoints(results)
#                 npy_path = os.path.join(DATA_PATH, action, str(sequence), f"{frame_num}.npy")
#                 np.save(npy_path, keypoints)

#                 # Break gracefully
#                 if cv2.waitKey(10) & 0xFF == ord('q'):
#                     print("User interrupted. Exiting...")
#                     break
                
# cap.release()
# cv2.destroyAllWindows()

# %%
from time import sleep
cap = cv2.VideoCapture(0)

def display_countdown(image, seconds, text, position=(100, 200)):
    """Display a countdown on the screen."""
    for i in range(seconds, 0, -1):
        # Clear the screen
        image.fill(0)  # This resets the frame to black for a clean slate
        # Display the countdown text
        cv2.putText(image, f"{text}: {i}", position, 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
        cv2.imshow('OpenCV Feed', image)
        if cv2.waitKey(1000) & 0xFF == ord('q'):  # Update every second
            break
# Set MediaPipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    # Loop through actions
    for action in actions:
        # Display a 10-second countdown before starting the action
        ret, frame = cap.read()
        display_countdown(frame, 10, f"Get Ready for {action}")

        # Loop through sequences (videos)
        for sequence in range(no_sequences):
            # Display a 3-second countdown before each gesture
            ret, frame = cap.read()
            display_countdown(frame, 3, f"Next Gesture {sequence + 1}")

            # Loop through frames
            for frame_num in range(sequence_length):
                # Read feed
                ret, frame = cap.read()
                if not ret:
                    print("Failed to read from webcam.")
                    break
                
                # Make detection
                image, results = mediapipe_detection(frame, holistic)
                
                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # Display starting message
                if frame_num == 0:
                    cv2.putText(
                        image, 'STARTING COLLECTION', (120, 200),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA
                    )
                    cv2.putText(
                        image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA
                    )
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)  # Pause for half a second
                else:
                    cv2.putText(
                        image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA
                    )
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), f"{frame_num}.npy")
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    print("User interrupted. Exiting...")
                    break
                
cap.release()
cv2.destroyAllWindows()
# Out:
# User interrupted. Exiting...
# User interrupted. Exiting...
# User interrupted. Exiting...
# User interrupted. Exiting...
# User interrupted. Exiting...
# User interrupted. Exiting...
# User interrupted. Exiting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 27
#      24 for sequence in range(no_sequences):
#      25     # Display a 3-second countdown before each gesture
#      26     ret, frame = cap.read()
# ---> 27     display_countdown(frame, 3, f"Next Gesture {sequence + 1}")
#      29     # Loop through frames
#      30     for frame_num in range(sequence_length):
#      31         # Read feed
#
# Cell In[11], line 13, in display_countdown(image, seconds, text, position)
#      10 cv2.putText(image, f"{text}: {i}", position,
#      11             cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
#      12 cv2.imshow('OpenCV Feed', image)
# ---> 13 if cv2.waitKey(1000) & 0xFF == ord('q'):  # Update every second
#      14     break
#
# KeyboardInterrupt:

# %% [markdown]
# # 6. Preprocess data and create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num,label in enumerate(actions)}
label_map

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (85, 30, 258)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='swish', input_shape=(30, 258)))  # Updated input shape
model.add(LSTM(128, return_sequences=True, activation='swish'))
model.add(LSTM(64, return_sequences=False, activation='swish'))
model.add(Dense(64, activation='swish'))
model.add(Dense(32, activation='swish'))
model.add(Dense(actions.shape[0], activation='softmax'))  # Number of classes

# %%
# example usage
res = [0.7, 0.2, 0.1]
actions[np.argmax(res)]

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - categorical_accuracy: 0.2623 - loss: 1.0985
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.5029 - loss: 1.0598
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.3758 - loss: 0.9014
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5577 - loss: 0.9553
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5088 - loss: 0.8895
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.6791 - loss: 0.9698
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7886 - loss: 0.9660
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.8297 - loss: 0.8618
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.7475 - loss: 0.8331
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.7926 - loss: 0.8746
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8571 - loss: 0.8547
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7124 - loss: 0.7543
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6790 - loss: 0.7145
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6830 - loss: 0.7819
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5910 - loss: 0.8959
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.5930 - loss: 0.8530
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.6849 - loss: 0.6148
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7143 - loss: 0.5418
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.8512 - loss: 0.5929
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.5773 - loss: 0.7357
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.6184 - loss: 0.7250
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.5930 - loss: 0.7402
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.6516 - loss: 0.6344
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.6771 - loss: 0.7811
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.5851 - loss: 0.7012
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.5206 - loss: 1.1106
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.6125 - loss: 0.7974
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.5343 - loss: 0.7372
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7104 - loss: 0.6391
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.8042 - loss: 0.5241
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.6575 - loss: 2.3508
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.4051 - loss: 1.4827
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.
# Epoch 1979/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.8043 - loss: 0.5224
# Epoch 1980/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.7064 - loss: 0.4921
# Epoch 1981/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.8415 - loss: 0.4226
# Epoch 1982/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.7240 - loss: 0.4225
# Epoch 1983/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.7886 - loss: 0.4915
# Epoch 1984/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.7652 - loss: 0.6433
# Epoch 1985/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.7299 - loss: 0.5422
# Epoch 1986/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6281 - loss: 0.8980
# Epoch 1987/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.6595 - loss: 0.6634
# Epoch 1988/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.7514 - loss: 0.7235
# Epoch 1989/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.6908 - loss: 0.8142
# Epoch 1990/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.6360 - loss: 0.6502
# Epoch 1991/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.7103 - loss: 0.7060
# Epoch 1992/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.7142 - loss: 0.6667
# Epoch 1993/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.7925 - loss: 0.5654
# Epoch 1994/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8493 - loss: 0.5278
# Epoch 1995/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.6028 - loss: 0.6703
# Epoch 1996/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.8297 - loss: 0.5630
# Epoch 1997/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.8102 - loss: 0.5686
# Epoch 1998/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.7319 - loss: 0.4732
# Epoch 1999/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.7730 - loss: 0.5637
# Epoch 2000/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.7045 - loss: 0.4311

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 30, 64)              │          82,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 30, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 711,755 (2.72 MB)
#  Trainable params: 237,251 (926.76 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 474,504 (1.81 MB)

# %% [markdown]
# # 8. Make Predictions

# %%
res=model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# array([[3.3859752e-21, 9.9999845e-01, 1.5188083e-06],
#        [1.9866706e-01, 7.6189667e-02, 7.2514325e-01],
#        [7.8428805e-01, 1.0526868e-04, 2.1560661e-01],
#        [1.2539380e-28, 1.0000000e+00, 1.4910359e-08],
#        [6.2118018e-29, 1.0000000e+00, 1.3285446e-08]], dtype=float32)

# %%
actions[np.argmax(res[4])]
# Out:
# 'Hello'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Thanks'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.keras')

# %%
del model

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('action.keras')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
yhat
# Out:
# [1, 1, 0, 1, 2]

# %%
ytrue
# Out:
# [1, 1, 2, 1, 2]

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[4, 1],
#         [0, 0]],
#
#        [[2, 0],
#         [0, 3]],
#
#        [[3, 0],
#         [1, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
# def prob_viz(res, actions, input_frame, colors):
#     output_frame = input_frame.copy()
#     for num, prob in enumerate(res):
#         cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[num], -1)
#         cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
#     return output_frame

# %%
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))

# %%
# # 1. New detection variables
# sequence = []
# sentence = []
# predictions = []
# threshold = 0.5

# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():

#         # Read feed
#         ret, frame = cap.read()

#         # Make detections
#         image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
#         # Draw landmarks
#         draw_styled_landmarks(image, results)
        
#         # 2. Prediction logic
#         keypoints = extract_keypoints(results)
#         sequence.append(keypoints)
        
#         if len(sequence) < 30:
#             sequence.append(keypoints)
#         else:
#             sequence.pop(0)
#             sequence.append(keypoints)

        
#         if len(sequence) == 30:
#             res = model.predict(np.expand_dims(sequence, axis=0))[0]
#             print(actions[np.argmax(res)])
#             predictions.append(np.argmax(res))
            
            
#         #3. Viz logic
#             if np.unique(predictions[-10:])[0]==np.argmax(res): 
#                 if res[np.argmax(res)] > threshold: 
                    
#                     if len(sentence) > 0: 
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])

#             if len(sentence) > 5: 
#                 sentence = sentence[-5:]

#             # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
#         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         cv2.putText(image, ' '.join(sentence), (3,30), 
#                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
#         # Show to screen
#         cv2.imshow('OpenCV Feed', image)

#         # Break gracefully
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

# %%
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'image' is not defined

# %%
# Detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Make detections
        image, results = mediapipe_detection(frame, holistic)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Prediction logic
        keypoints = extract_keypoints(results)
        if len(sequence) < 30:
            sequence.append(keypoints)
            continue  # Skip prediction until 30 frames are collected

        sequence.pop(0)
        sequence.append(keypoints)

        res = model.predict(np.expand_dims(sequence, axis=0))[0]
        predictions.append(np.argmax(res))

        if len(predictions) >= 10:
            from scipy.stats import mode
            mode_result = mode(predictions[-10:])
            most_frequent = mode_result.mode[0] if len(mode_result.mode) > 0 else None
            if most_frequent is not None and most_frequent == np.argmax(res) and res[np.argmax(res)] > threshold:
                if len(sentence) == 0 or actions[np.argmax(res)] != sentence[-1]:
                    sentence.append(actions[np.argmax(res)])

        if len(sentence) > 5:
            sentence = sentence[-5:]

        # Viz probabilities
        image = prob_viz(res, actions, image, colors)

        # Display sentence
        cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 36
#      34 from scipy.stats import mode
#      35 mode_result = mode(predictions[-10:])
# ---> 36 most_frequent = mode_result.mode[0] if len(mode_result.mode) > 0 else None
#      37 if most_frequent is not None and most_frequent == np.argmax(res) and res[np.argmax(res)] > threshold:
#      38     if len(sentence) == 0 or actions[np.argmax(res)] != sentence[-1]:
#
# TypeError: object of type 'numpy.int64' has no len()
